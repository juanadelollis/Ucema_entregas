# %%
import pandas as pd

# %%
arboles= pd.read_csv("https://raw.githubusercontent.com/MumukiProject/datasets/master/arbolado-publico-lineal.csv")
arboles
# Out:
#              long        lat site_type      tree_id  height  diameter  \
# 0      -58.389059 -34.620026     Árbol       2430.0     7.0      20.0
# 1      -58.389211 -34.620034     Árbol       2431.0     8.0      33.0
# 2      -58.389269 -34.620037     Árbol       2432.0     2.0       3.0
# 3      -58.389525 -34.620052     Árbol       2433.0     9.0      17.0
# 4      -58.389608 -34.620057     Árbol       2434.0     6.0      13.0
# ...           ...        ...       ...          ...     ...       ...
# 372689 -58.493294 -34.623746     Árbol  938000239.0    10.0      52.0
# 372690 -58.493241 -34.623788     Árbol  938000240.0    11.0      60.0
# 372691 -58.493176 -34.623840     Árbol  938000241.0    10.0      56.0
# 372692 -58.493116 -34.623887     Árbol  938000242.0    10.0      58.0
# 372693 -58.493086 -34.624042     Árbol  938000243.0     3.0       5.0
#
#         inclination  species_id   fam_name       gen_name  \
# 0              17.0         1.0   Oleáceas       Fraxinus
# ...

# %%
arboles["height"].max()
# Out:
# 60.0

# %%
arboles["height"].median()
# Out:
# 8.0

# %%
arboles["diameter"].mean()
# Out:
# 31.94135134990099

# %%
arboles["diameter"].quantile(0.75)
# Out:
# 43.0

# %%
arboles.describe()
# Out:
#                 long            lat       tree_id         height  \
# count  372659.000000  372659.000000  3.726940e+05  372694.000000
# mean      -58.458556     -34.613312  2.710744e+07       8.473085
# std         0.041818       0.034253  4.134081e+07       4.576827
# min       -58.530413     -34.702639  2.430000e+03       0.000000
# 25%       -58.491353     -34.639264  1.661592e+05       5.000000
# 50%       -58.465525     -34.615744  1.700314e+07       8.000000
# 75%       -58.428724     -34.586780  3.810204e+07      11.000000
# max       -58.342784     -34.534262  9.380002e+08      60.000000
#
#             diameter    inclination     species_id         comuna  \
# count  372694.000000  372686.000000  372694.000000  372694.000000
# mean       31.941351       3.069834      38.703695       9.124542
# std        20.207274       6.029981     141.187865       3.866489
# min         0.000000       0.000000       1.000000       1.000000
# ...

# %%
arboles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372694 entries, 0 to 372693
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   long           372659 non-null  float64
#  1   lat            372659 non-null  float64
#  2   site_type      372694 non-null  object
#  3   tree_id        372694 non-null  float64
#  4   height         372694 non-null  float64
#  5   diameter       372694 non-null  float64
#  6   inclination    372686 non-null  float64
#  7   species_id     372694 non-null  float64
#  8   fam_name       372694 non-null  object
#  9   gen_name       372694 non-null  object
#  10  sci_name       372694 non-null  object
#  11  comm_name      372694 non-null  object
#  12  fol_type       372694 non-null  object
#  13  origin         372694 non-null  object
#  14  man_code       372694 non-null  object
#  15  neighbourhood  372694 non-null  object
#  16  comuna         372694 non-null  float64
# ...

# %%
arboles["height"] >= 7
# Out:
# 0          True
# 1          True
# 2         False
# 3          True
# 4         False
#           ...
# 372689     True
# 372690     True
# 372691     True
# 372692     True
# 372693    False
# Name: height, Length: 372694, dtype: bool

# %% [markdown]
# Leccion 4: ejercicio 2

# %%
arboles_de_palermo = arboles[arboles["neighbourhood"] == "PALERMO"]
arboles_de_palermo
# Out:
#              long        lat site_type      tree_id  height  diameter  \
# 95041  -58.437231 -34.584817     Árbol     168390.0     7.0      41.0
# 95042  -58.437276 -34.584783     Árbol     168391.0    15.0      43.0
# 95043  -58.437416 -34.584678     Árbol     168392.0     3.0      13.0
# 95044  -58.437468 -34.584640     Árbol     168393.0     5.0      16.0
# 95045  -58.437551 -34.584578     Árbol     168394.0     7.0      17.0
# ...           ...        ...       ...          ...     ...       ...
# 370835 -58.430834 -34.592673     Árbol  219004408.0    14.0      40.0
# 370836 -58.430746 -34.592731     Árbol  219004409.0     7.0      25.0
# 370837 -58.430677 -34.592778     Árbol  219004410.0     7.0      24.0
# 370838 -58.430608 -34.592825     Árbol  219004411.0     9.0      34.0
# 370839 -58.430531 -34.592876     Árbol  219004412.0     7.0      22.0
#
#         inclination  species_id       fam_name   gen_name  \
# 95041          35.0         7.0      Aceráceas       Acer
# ...

# %% [markdown]
# Leccion 4: Ejercicio 3

# %%
sauces= arboles[arboles["comm_name"].str.startswith("Sauce")]
sauces
# Out:
#              long        lat site_type      tree_id  height  diameter  \
# 654    -58.401518 -34.594771     Árbol       3202.0    24.0      70.0
# 1233   -58.398963 -34.597287     Árbol       3849.0     9.0      32.0
# 1286   -58.399023 -34.595214     Árbol       3907.0    21.0      63.0
# 1294   -58.399703 -34.594786     Árbol       3916.0     9.0      24.0
# 2140   -58.393885 -34.597293     Árbol       4916.0     7.0      23.0
# ...           ...        ...       ...          ...     ...       ...
# 371317 -58.427520 -34.649188     Árbol  219004895.0     6.0      16.0
# 371710 -58.408170 -34.645448     Árbol  219005288.0    12.0      56.0
# 372282 -58.374756 -34.652102     Árbol  219005860.0    11.0      53.0
# 372283 -58.374683 -34.652081     Árbol  219005861.0    11.0      54.0
# 372596 -58.507724 -34.604768     Árbol  904001509.0     7.0      27.0
#
#         inclination  species_id    fam_name gen_name                 sci_name  \
# ...

# %% [markdown]
# Leccion 4: ejercicio 4

# %%
arboles[(arboles["comuna"] == 10) & arboles["fam_name"].str.startswith("Oleáceas")]
# Out:
#              long        lat site_type      tree_id  height  diameter  \
# 66356  -58.474736 -34.636657     Árbol     131732.0     4.0      18.0
# 66357  -58.474679 -34.636636     Árbol     131733.0     6.0      30.0
# 66358  -58.474621 -34.636615     Árbol     131734.0     7.0      26.0
# 66360  -58.474280 -34.636492     Árbol     131736.0     3.0      12.0
# 66361  -58.474209 -34.636466     Árbol     131737.0     3.0      14.0
# ...           ...        ...       ...          ...     ...       ...
# 372675 -58.493316 -34.624010     Árbol  938000225.0    10.0      22.0
# 372677 -58.494081 -34.623261     Árbol  938000227.0     8.0      28.0
# 372678 -58.493912 -34.623256     Árbol  938000228.0    11.0      50.0
# 372679 -58.493869 -34.623289     Árbol  938000229.0     5.0       8.0
# 372682 -58.493657 -34.623458     Árbol  938000232.0    14.0      48.0
#
#         inclination  species_id  fam_name  gen_name                sci_name  \
# ...

# %% [markdown]
# Leccion 4: ejercicio 5

# %%
arboles[(arboles["neighbourhood"] == "Balvanera") | arboles["comuna"] == 10]
# Out:
# Empty DataFrame
# Columns: [long, lat, site_type, tree_id, height, diameter, inclination, species_id, fam_name, gen_name, sci_name, comm_name, fol_type, origin, man_code, neighbourhood, comuna, street, num1, num2]
# Index: []

# %% [markdown]
# Leccion 4: ejercicio 6

# %%
arboles[
     (arboles["neighbourhood"] == "FLORESTA") 
     | (arboles["neighbourhood"] == "RECOLETA") 
     | (arboles["neighbourhood"] == "BELGRANO")
     | (arboles["neighbourhood"] == "NUÑEZ")]
# Out:
#              long        lat site_type      tree_id  height  diameter  \
# 515    -58.389869 -34.598446     Árbol       3037.0     2.0       4.0
# 516    -58.390172 -34.598468     Árbol       3038.0     3.0       5.0
# 517    -58.390232 -34.598472     Árbol       3039.0    40.0       5.0
# 518    -58.390322 -34.598478     Árbol       3040.0    40.0       4.0
# 519    -58.389784 -34.598304     Árbol       3044.0     7.0      11.0
# ...           ...        ...       ...          ...     ...       ...
# 372689 -58.493294 -34.623746     Árbol  938000239.0    10.0      52.0
# 372690 -58.493241 -34.623788     Árbol  938000240.0    11.0      60.0
# 372691 -58.493176 -34.623840     Árbol  938000241.0    10.0      56.0
# 372692 -58.493116 -34.623887     Árbol  938000242.0    10.0      58.0
# 372693 -58.493086 -34.624042     Árbol  938000243.0     3.0       5.0
#
#         inclination  species_id       fam_name       gen_name  \
# 515             0.0         6.0       Moráceas          Ficus
# ...

# %%
arboles[arboles["neighbourhood"].isin(["FLORESTA", "RECOLETA", "BELGRANO", "NUÑEZ"])]
# Out:
#              long        lat site_type      tree_id  height  diameter  \
# 515    -58.389869 -34.598446     Árbol       3037.0     2.0       4.0
# 516    -58.390172 -34.598468     Árbol       3038.0     3.0       5.0
# 517    -58.390232 -34.598472     Árbol       3039.0    40.0       5.0
# 518    -58.390322 -34.598478     Árbol       3040.0    40.0       4.0
# 519    -58.389784 -34.598304     Árbol       3044.0     7.0      11.0
# ...           ...        ...       ...          ...     ...       ...
# 372689 -58.493294 -34.623746     Árbol  938000239.0    10.0      52.0
# 372690 -58.493241 -34.623788     Árbol  938000240.0    11.0      60.0
# 372691 -58.493176 -34.623840     Árbol  938000241.0    10.0      56.0
# 372692 -58.493116 -34.623887     Árbol  938000242.0    10.0      58.0
# 372693 -58.493086 -34.624042     Árbol  938000243.0     3.0       5.0
#
#         inclination  species_id       fam_name       gen_name  \
# 515             0.0         6.0       Moráceas          Ficus
# ...

# %% [markdown]
# Leccion 4: ejercicio 7

# %%
arboles[~arboles["comm_name"].str.startswith("Fresno")]
# Out:
#              long        lat site_type      tree_id  height  diameter  \
# 2      -58.389269 -34.620037     Árbol       2432.0     2.0       3.0
# 3      -58.389525 -34.620052     Árbol       2433.0     9.0      17.0
# 5      -58.389665 -34.620060     Árbol       2435.0     3.0       2.0
# 10     -58.390168 -34.619941     Árbol       2441.0     7.0      27.0
# 34     -58.388962 -34.619363     Árbol       2467.0    11.0      18.0
# ...           ...        ...       ...          ...     ...       ...
# 372689 -58.493294 -34.623746     Árbol  938000239.0    10.0      52.0
# 372690 -58.493241 -34.623788     Árbol  938000240.0    11.0      60.0
# 372691 -58.493176 -34.623840     Árbol  938000241.0    10.0      56.0
# 372692 -58.493116 -34.623887     Árbol  938000242.0    10.0      58.0
# 372693 -58.493086 -34.624042     Árbol  938000243.0     3.0       5.0
#
#         inclination  species_id   fam_name       gen_name  \
# 2               0.0         9.0   Oleáceas      Ligustrum
# ...

# %% [markdown]
# Leccion 4: ejercicio 8

# %%
arboles[arboles["street"].isna()]
# Out:
#              long        lat site_type     tree_id  height  diameter  \
# 13667  -58.399585 -34.602789     Árbol     18300.0     4.0       7.0
# 30148  -58.395248 -34.626713     Árbol     68384.0    10.0      50.0
# 58994  -58.443560 -34.615603     Árbol    123412.0     3.0      12.0
# 81182  -58.473926 -34.564482     Árbol    150590.0    11.0      50.0
# 84159  -58.463787 -34.627756     Árbol    154078.0    11.0      26.0
# 160395 -58.494237 -34.612140     Árbol  12000808.0    10.0      20.0
# 186154 -58.454284 -34.567895     Árbol  17002947.0     6.0       9.0
# 218616 -58.488071 -34.651757     Árbol  26103081.0     9.0      30.0
# 241669 -58.488008 -34.617925     Árbol  31001312.0    12.0      57.0
# 270084 -58.463276 -34.611764     Árbol  35001504.0     6.0      11.0
# 277992 -58.487785 -34.605276     Árbol  38000673.0    18.0      63.0
# 308884 -58.402492 -34.639113     Árbol  45004386.0     2.0       3.0
#
#         inclination  species_id     fam_name       gen_name  \
# ...

# %% [markdown]
# Leccion 4: ejercicio 9

# %%
len(arboles[arboles["num1"].notna ()])
# Out:
# 372635

# %% [markdown]
# Leccion 4: ejercicio 10

# %%
arboles.dropna(inplace=True)

# %% [markdown]
# Leccion 4: ejercicio 11

# %%
arboles.dropna(subset=["long","lat"])
# Out:
#              long        lat site_type      tree_id  height  diameter  \
# 0      -58.389059 -34.620026     Árbol       2430.0     7.0      20.0
# 1      -58.389211 -34.620034     Árbol       2431.0     8.0      33.0
# 2      -58.389269 -34.620037     Árbol       2432.0     2.0       3.0
# 3      -58.389525 -34.620052     Árbol       2433.0     9.0      17.0
# 4      -58.389608 -34.620057     Árbol       2434.0     6.0      13.0
# ...           ...        ...       ...          ...     ...       ...
# 372689 -58.493294 -34.623746     Árbol  938000239.0    10.0      52.0
# 372690 -58.493241 -34.623788     Árbol  938000240.0    11.0      60.0
# 372691 -58.493176 -34.623840     Árbol  938000241.0    10.0      56.0
# 372692 -58.493116 -34.623887     Árbol  938000242.0    10.0      58.0
# 372693 -58.493086 -34.624042     Árbol  938000243.0     3.0       5.0
#
#         inclination  species_id   fam_name       gen_name  \
# 0              17.0         1.0   Oleáceas       Fraxinus
# ...

# %% [markdown]
# Leccion 4: ejercicio 12

# %%
arboles["inclination"].fillna(arboles["inclination"].mean(), inplace=True)

# %% [markdown]
# Leccion 4: ejercicio 13        arboles(arboles["diameter"].quantile(0.98)) % (arboles["diameter"] <= )

# %% [markdown]
# Leccion 5: ejercicio 4

# %%
import pandas as pd
cruceros_originales = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vRSa9oM9fC-QlT7VOeGhZQtrWnlNSTsk3U8DWGTOXUWtPH6u9o5O5eZ0kTg8mFTwAn9vMdGRK7o2SPB/pub?gid=751983160&single=true&output=csv")
cruceros = cruceros_originales.copy()

# %%
cruceros.head()
# Out:
#    cruise_id  country_id         country        date  date_id  port_id  \
# 0         41          57           Suiza  2016-12-02    13485        1
# 1         42          59  Otro de Europa  2016-12-02    13485        1
# 2         43          41          Canada  2016-12-02    13485        1
# 3         44          32        Colombia  2016-12-02    13485        1
# 4         45          70          EE.UU.  2016-12-02    13485        1
#
#          port  total_people  visits_amount  total_expenses  tours_expenses  \
# 0  Montevideo             6              0             0.0             0.0
# 1  Montevideo             4              0           200.0           100.0
# 2  Montevideo             4              0           100.0           100.0
# 3  Montevideo             3              0           600.0             0.0
# 4  Montevideo             2              0           200.0             0.0
#
#    feed_expenses  transport_expenses  shopping_expenses  other_expenses
# ...

# %%
cruceros["country"]
# Out:
# 0                 Suiza
# 1        Otro de Europa
# 2                Canada
# 3              Colombia
# 4                EE.UU.
#               ...
# 12011         Argentina
# 12012         Argentina
# 12013         Argentina
# 12014         Argentina
# 12015         Argentina
# Name: country, Length: 12016, dtype: object

# %%
cruceros["region"] = cruceros["country"].map({
    "Uruguay": "Nacional",
    "Argentina": "Regional",
    "Brasil": "Regional"})

cruceros["region"]
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 12011    Regional
# 12012    Regional
# 12013    Regional
# 12014    Regional
# 12015    Regional
# Name: region, Length: 12016, dtype: object

# %%
cruceros["region"].fillna("No regional")
# Out:
# 0        No regional
# 1        No regional
# 2        No regional
# 3        No regional
# 4        No regional
#             ...
# 12011       Regional
# 12012       Regional
# 12013       Regional
# 12014       Regional
# 12015       Regional
# Name: region, Length: 12016, dtype: object

# %%
cruceros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12016 entries, 0 to 12015
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   cruise_id           12016 non-null  int64
#  1   country_id          12016 non-null  int64
#  2   country             12016 non-null  object
#  3   date                12016 non-null  object
#  4   date_id             12016 non-null  int64
#  5   port_id             12016 non-null  int64
#  6   port                12016 non-null  object
#  7   total_people        12016 non-null  int64
#  8   visits_amount       12016 non-null  int64
#  9   total_expenses      12016 non-null  float64
#  10  tours_expenses      12016 non-null  float64
#  11  feed_expenses       12016 non-null  float64
#  12  transport_expenses  12016 non-null  float64
#  13  shopping_expenses   12016 non-null  float64
#  14  other_expenses      12016 non-null  float64
# ...

# %%
cruceros["region", "visits_amount"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\msjan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\msjan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\msjan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('region', 'visits_amount')
#
# ...

# %%
import pandas as pd

# %%
producto = ["Shampoo sólido","Crema de manos"]

stock = [5,6]

precio = [300, 600]

indices = [1, 2]

productos = {"Producto": producto, "Stock": stock, "Precio unitario": precio}

df = pd.DataFrame(data=productos, index=indices)
df
# Out:
#          Producto  Stock  Precio unitario
# 1  Shampoo sólido      5              300
# 2  Crema de manos      6              600

# %%
print(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Producto</th>
#       <th>Stock</th>
#       <th>Precio unitario</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Shampoo sólido</td>
#       <td>5</td>
#       <td>300</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Crema de manos</td>
#       <td>6</td>
#       <td>600</td>
#     </tr>
#   </tbody>
# </table>
